# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import re
import sklearn
from sklearn import __version__ as sklearn_version
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve, cross_val_score, KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, PolynomialFeatures, scale
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression, RFE
import datetime
from sklearn.metrics import accuracy_score
import statsmodels.api as sm
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import QuantileTransformer

import warnings # supress warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('600K US Housing Properties.csv', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   property_url        600000 non-null  object
#  1   property_id         600000 non-null  int64
#  2   address             600000 non-null  object
#  3   street_name         599869 non-null  object
#  4   apartment           14815 non-null   object
#  5   city                599999 non-null  object
#  6   state               599999 non-null  object
#  7   latitude            529122 non-null  float64
#  8   longitude           529122 non-null  float64
#  9   postcode            599970 non-null  object
#  10  price               600000 non-null  float64
#  11  bedroom_number      443845 non-null  float64
#  12  bathroom_number     471733 non-null  float64
#  13  price_per_unit      435365 non-null  float64
#  14  living_space        447847 non-null  float64
#  15  land_space          515119 non-null  float64
#  16  land_space_unit     515119 non-null  object
#  17  broker_id           0 non-null       float64
#  18  property_type       600000 non-null  object
#  19  property_status     600000 non-null  object
#  20  year_build          0 non-null       float64
#  21  total_num_units     0 non-null       float64
#  22  listing_age         600000 non-null  int64
#  23  RunDate             600000 non-null  object
#  24  agency_name         444524 non-null  object
#  25  agent_name          0 non-null       float64
#  26  agent_phone         0 non-null       float64
#  27  is_owned_by_zillow  600000 non-null  int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 128.2+ MB

# %%
description = df.describe(include='all')
description
# Out:
#                                              property_url   property_id  \
# count                                              600000  6.000000e+05
# unique                                             600000           NaN
# top     https://www.zillow.com/homedetails/3-Plat-83-1...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  8.885042e+08
# std                                                   NaN  9.724708e+08
# min                                                   NaN  2.700000e+01
# 25%                                                   NaN  5.402143e+07
# 50%                                                   NaN  2.066090e+08
# 75%                                                   NaN  2.066867e+09
# max                                                   NaN  2.146997e+09
#
#                                           address            street_name  \
# count                                      600000                 599869
# unique                                     598588                 339224
# top     (undisclosed Address), Rockport, TX 78382  (undisclosed Address)
# freq                                           36                   1713
# mean                                          NaN                    NaN
# std                                           NaN                    NaN
# min                                           NaN                    NaN
# 25%                                           NaN                    NaN
# 50%                                           NaN                    NaN
# 75%                                           NaN                    NaN
# max                                           NaN                    NaN
#
#        apartment     city   state       latitude      longitude postcode  ...  \
# count      14815   599999  599999  529122.000000  529122.000000   599970  ...
# unique      2664     7977      25            NaN            NaN    10820  ...
# top            1  Chicago      TX            NaN            NaN    84043  ...
# freq         312    14138  146636            NaN            NaN     1102  ...
# mean         NaN      NaN     NaN      36.282379    -105.813906      NaN  ...
# std          NaN      NaN     NaN       5.673355      13.464633      NaN  ...
# min          NaN      NaN     NaN      18.985142    -165.408250      NaN  ...
# 25%          NaN      NaN     NaN      32.612112    -117.346079      NaN  ...
# 50%          NaN      NaN     NaN      35.403568    -101.897378      NaN  ...
# 75%          NaN      NaN     NaN      39.661674     -95.354245      NaN  ...
# max          NaN      NaN     NaN      71.299170     -87.525570      NaN  ...
#
#         property_type  property_status  year_build  total_num_units  \
# count          600000           600000         0.0              0.0
# unique              7                2         NaN              NaN
# top     SINGLE_FAMILY         FOR_SALE         NaN              NaN
# freq           354366           383365         NaN              NaN
# mean              NaN              NaN         NaN              NaN
# std               NaN              NaN         NaN              NaN
# min               NaN              NaN         NaN              NaN
# 25%               NaN              NaN         NaN              NaN
# 50%               NaN              NaN         NaN              NaN
# 75%               NaN              NaN         NaN              NaN
# max               NaN              NaN         NaN              NaN
#
#         listing_age              RunDate             agency_name  agent_name  \
# count      600000.0               600000                  444524         0.0
# unique          NaN                    1                   34372         NaN
# top             NaN  2022-04-24 07:34:15  Coldwell Banker Realty         NaN
# freq            NaN               600000                    5936         NaN
# mean           -1.0                  NaN                     NaN         NaN
# std             0.0                  NaN                     NaN         NaN
# min            -1.0                  NaN                     NaN         NaN
# 25%            -1.0                  NaN                     NaN         NaN
# 50%            -1.0                  NaN                     NaN         NaN
# 75%            -1.0                  NaN                     NaN         NaN
# max            -1.0                  NaN                     NaN         NaN
#
#        agent_phone is_owned_by_zillow
# count          0.0      600000.000000
# unique         NaN                NaN
# top            NaN                NaN
# freq           NaN                NaN
# mean           NaN           0.000498
# std            NaN           0.022318
# min            NaN           0.000000
# 25%            NaN           0.000000
# 50%            NaN           0.000000
# 75%            NaN           0.000000
# max            NaN           1.000000
#
# [11 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['property_url', 'property_id', 'address', 'street_name', 'apartment',
#        'city', 'state', 'latitude', 'longitude', 'postcode', 'price',
#        'bedroom_number', 'bathroom_number', 'price_per_unit', 'living_space',
#        'land_space', 'land_space_unit', 'broker_id', 'property_type',
#        'property_status', 'year_build', 'total_num_units', 'listing_age',
#        'RunDate', 'agency_name', 'agent_name', 'agent_phone',
#        'is_owned_by_zillow'],
#       dtype='object')

# %%
df = df.drop(df[df.property_type == 'LOT'].index)
df = df.drop(df[df.living_space == 0].index)
df = df.drop(df[df.price == 0].index)
df = df[df.state == 'TX']

# %%
#Land space is an important metric for the price of the house but this dataset has multiple units
#All the values with 'acres' unit changed to 'sqft'
df.loc[df['land_space_unit']=='acres', 'land_space'] = df['land_space']*43560.00
df.loc[df['land_space_unit']=='acres', 'land_space_unit']='sqft'
df[['land_space','land_space_unit']]
# Out:
#         land_space land_space_unit
# 180271    6969.600            sqft
# 180273   12632.400            sqft
# 180275   11325.600            sqft
# 180277   15246.000            sqft
# 180279    6000.000            sqft
# ...            ...             ...
# 446346    8145.720            sqft
# 446348    3920.400            sqft
# 446350    4356.000            sqft
# 446352    4299.372            sqft
# 446354    9016.920            sqft
#
# [113297 rows x 2 columns]

# %%
df = df.drop(columns=['property_url', 'property_id', 'address', 'street_name', 'apartment', 'city', 'state', 'latitude', 'longitude','price_per_unit', 'land_space_unit', 'broker_id','property_status', 'year_build', 'total_num_units', 'listing_age',
       'RunDate', 'agency_name', 'agent_name', 'agent_phone',
       'is_owned_by_zillow'])

# %%
description = df.describe(include='all')
description
# Out:
#        postcode         price  bedroom_number  bathroom_number  living_space  \
# count    113297  1.132970e+05   110799.000000    112676.000000  1.109490e+05
# unique     1661           NaN             NaN              NaN           NaN
# top       75126           NaN             NaN              NaN           NaN
# freq        964           NaN             NaN              NaN           NaN
# mean        NaN  5.191826e+05        3.440031         2.679117  2.484810e+03
# std         NaN  7.836710e+05        1.023723         1.195078  3.747852e+04
# min         NaN  1.000000e+00        0.000000         0.000000  1.000000e+00
# 25%         NaN  2.728000e+05        3.000000         2.000000  1.590000e+03
# 50%         NaN  3.800000e+05        3.000000         3.000000  2.052000e+03
# 75%         NaN  5.499000e+05        4.000000         3.000000  2.698000e+03
# max         NaN  5.000000e+07       93.000000        44.000000  1.140106e+07
#
#           land_space  property_type
# count   9.127400e+04         113297
# unique           NaN              6
# top              NaN  SINGLE_FAMILY
# freq             NaN         101682
# mean    2.915174e+05            NaN
# std     9.626307e+06            NaN
# min    -1.089000e+04            NaN
# 25%     6.124134e+03            NaN
# 50%     8.424504e+03            NaN
# 75%     1.769734e+04            NaN
# max     2.011322e+09            NaN

# %%
df.isna().sum()
# Out:
# postcode               0
# price                  0
# bedroom_number      2498
# bathroom_number      621
# living_space        2348
# land_space         22023
# property_type          0
# dtype: int64

# %%
df['bedroom_number'] = df['bedroom_number'].fillna(df['bedroom_number'].median())
df['bathroom_number'] = df['bathroom_number'].fillna(df['bathroom_number'].median())
df['living_space'] = df['living_space'].fillna(df['living_space'].median())
df['land_space'] = df['land_space'].fillna(df['land_space'].median())

# %%
df.isna().sum()
# Out:
# postcode           0
# price              0
# bedroom_number     0
# bathroom_number    0
# living_space       0
# land_space         0
# property_type      0
# dtype: int64

# %%
# A crucial categorical feature 'property_type' is categorical variable so I wanted to transform that to a numeric one
dummies=pd.get_dummies(df[['postcode','property_type']], drop_first=True)
dummies
# Out:
#         postcode_11111  postcode_73870  postcode_75001  postcode_75002  \
# 180271               0               0               0               0
# 180273               0               0               0               0
# 180275               0               0               0               0
# 180277               0               0               0               0
# 180279               0               0               0               0
# ...                ...             ...             ...             ...
# 446346               0               0               0               0
# 446348               0               0               0               0
# 446350               0               0               0               0
# 446352               0               0               0               0
# 446354               0               0               0               0
#
#         postcode_75006  postcode_75007  postcode_75009  postcode_75010  \
# 180271               0               0               0               0
# 180273               0               0               0               0
# 180275               0               0               0               0
# 180277               0               0               0               0
# 180279               0               0               0               0
# ...                ...             ...             ...             ...
# 446346               0               0               0               0
# 446348               0               0               0               0
# 446350               0               0               0               0
# 446352               0               0               0               0
# 446354               0               0               0               0
#
#         postcode_75013  postcode_75017  ...  postcode_79934  postcode_79935  \
# 180271               0               0  ...               0               0
# 180273               0               0  ...               0               0
# 180275               0               0  ...               0               0
# 180277               0               0  ...               0               0
# 180279               0               0  ...               0               0
# ...                ...             ...  ...             ...             ...
# 446346               0               0  ...               0               0
# 446348               0               0  ...               0               0
# 446350               0               0  ...               0               0
# 446352               0               0  ...               0               0
# 446354               0               0  ...               0               0
#
#         postcode_79936  postcode_79938  postcode_97316  property_type_CONDO  \
# 180271               0               0               0                    0
# 180273               0               0               0                    0
# 180275               0               0               0                    0
# 180277               0               0               0                    0
# 180279               0               0               0                    0
# ...                ...             ...             ...                  ...
# 446346               0               0               0                    0
# 446348               0               0               0                    0
# 446350               0               0               0                    0
# 446352               0               0               0                    0
# 446354               0               0               0                    0
#
#         property_type_MANUFACTURED  property_type_MULTI_FAMILY  \
# 180271                           0                           0
# 180273                           0                           0
# 180275                           0                           0
# 180277                           0                           0
# 180279                           0                           1
# ...                            ...                         ...
# 446346                           0                           0
# 446348                           0                           0
# 446350                           0                           0
# 446352                           0                           0
# 446354                           0                           0
#
#         property_type_SINGLE_FAMILY  property_type_TOWNHOUSE
# 180271                            1                        0
# 180273                            1                        0
# 180275                            1                        0
# 180277                            1                        0
# 180279                            0                        0
# ...                             ...                      ...
# 446346                            1                        0
# 446348                            1                        0
# 446350                            1                        0
# 446352                            1                        0
# 446354                            1                        0
#
# [113297 rows x 1665 columns]

# %%
df = pd.concat([df,dummies],axis='columns')
df
# Out:
#        postcode     price  bedroom_number  bathroom_number  living_space  \
# 180271    79903  239500.0             5.0              3.0        1692.0
# 180273    79925  165000.0             4.0              2.0        1650.0
# 180275    79905  118000.0             4.0              1.0        1918.0
# 180277    79903  414700.0             4.0              3.0        3119.0
# 180279    79905  260000.0             3.0              3.0        3267.0
# ...         ...       ...             ...              ...           ...
# 446346    75023  393000.0             3.0              2.0        1717.0
# 446348    75023  315000.0             3.0              3.0        1754.0
# 446350    75023  360000.0             4.0              3.0        2068.0
# 446352    75023  447000.0             4.0              3.0        2111.0
# 446354    75023  377000.0             3.0              2.0        1848.0
#
#         land_space  property_type  postcode_11111  postcode_73870  \
# 180271    6969.600  SINGLE_FAMILY               0               0
# 180273   12632.400  SINGLE_FAMILY               0               0
# 180275   11325.600  SINGLE_FAMILY               0               0
# 180277   15246.000  SINGLE_FAMILY               0               0
# 180279    6000.000   MULTI_FAMILY               0               0
# ...            ...            ...             ...             ...
# 446346    8145.720  SINGLE_FAMILY               0               0
# 446348    3920.400  SINGLE_FAMILY               0               0
# 446350    4356.000  SINGLE_FAMILY               0               0
# 446352    4299.372  SINGLE_FAMILY               0               0
# 446354    9016.920  SINGLE_FAMILY               0               0
#
#         postcode_75001  ...  postcode_79934  postcode_79935  postcode_79936  \
# 180271               0  ...               0               0               0
# 180273               0  ...               0               0               0
# 180275               0  ...               0               0               0
# 180277               0  ...               0               0               0
# 180279               0  ...               0               0               0
# ...                ...  ...             ...             ...             ...
# 446346               0  ...               0               0               0
# 446348               0  ...               0               0               0
# 446350               0  ...               0               0               0
# 446352               0  ...               0               0               0
# 446354               0  ...               0               0               0
#
#         postcode_79938  postcode_97316  property_type_CONDO  \
# 180271               0               0                    0
# 180273               0               0                    0
# 180275               0               0                    0
# 180277               0               0                    0
# 180279               0               0                    0
# ...                ...             ...                  ...
# 446346               0               0                    0
# 446348               0               0                    0
# 446350               0               0                    0
# 446352               0               0                    0
# 446354               0               0                    0
#
#         property_type_MANUFACTURED  property_type_MULTI_FAMILY  \
# 180271                           0                           0
# 180273                           0                           0
# 180275                           0                           0
# 180277                           0                           0
# 180279                           0                           1
# ...                            ...                         ...
# 446346                           0                           0
# 446348                           0                           0
# 446350                           0                           0
# 446352                           0                           0
# 446354                           0                           0
#
#         property_type_SINGLE_FAMILY  property_type_TOWNHOUSE
# 180271                            1                        0
# 180273                            1                        0
# 180275                            1                        0
# 180277                            1                        0
# 180279                            0                        0
# ...                             ...                      ...
# 446346                            1                        0
# 446348                            1                        0
# 446350                            1                        0
# 446352                            1                        0
# 446354                            1                        0
#
# [113297 rows x 1672 columns]

# %%
df = df.drop(columns=['postcode','property_type'])
df
# Out:
#            price  bedroom_number  bathroom_number  living_space  land_space  \
# 180271  239500.0             5.0              3.0        1692.0    6969.600
# 180273  165000.0             4.0              2.0        1650.0   12632.400
# 180275  118000.0             4.0              1.0        1918.0   11325.600
# 180277  414700.0             4.0              3.0        3119.0   15246.000
# 180279  260000.0             3.0              3.0        3267.0    6000.000
# ...          ...             ...              ...           ...         ...
# 446346  393000.0             3.0              2.0        1717.0    8145.720
# 446348  315000.0             3.0              3.0        1754.0    3920.400
# 446350  360000.0             4.0              3.0        2068.0    4356.000
# 446352  447000.0             4.0              3.0        2111.0    4299.372
# 446354  377000.0             3.0              2.0        1848.0    9016.920
#
#         postcode_11111  postcode_73870  postcode_75001  postcode_75002  \
# 180271               0               0               0               0
# 180273               0               0               0               0
# 180275               0               0               0               0
# 180277               0               0               0               0
# 180279               0               0               0               0
# ...                ...             ...             ...             ...
# 446346               0               0               0               0
# 446348               0               0               0               0
# 446350               0               0               0               0
# 446352               0               0               0               0
# 446354               0               0               0               0
#
#         postcode_75006  ...  postcode_79934  postcode_79935  postcode_79936  \
# 180271               0  ...               0               0               0
# 180273               0  ...               0               0               0
# 180275               0  ...               0               0               0
# 180277               0  ...               0               0               0
# 180279               0  ...               0               0               0
# ...                ...  ...             ...             ...             ...
# 446346               0  ...               0               0               0
# 446348               0  ...               0               0               0
# 446350               0  ...               0               0               0
# 446352               0  ...               0               0               0
# 446354               0  ...               0               0               0
#
#         postcode_79938  postcode_97316  property_type_CONDO  \
# 180271               0               0                    0
# 180273               0               0                    0
# 180275               0               0                    0
# 180277               0               0                    0
# 180279               0               0                    0
# ...                ...             ...                  ...
# 446346               0               0                    0
# 446348               0               0                    0
# 446350               0               0                    0
# 446352               0               0                    0
# 446354               0               0                    0
#
#         property_type_MANUFACTURED  property_type_MULTI_FAMILY  \
# 180271                           0                           0
# 180273                           0                           0
# 180275                           0                           0
# 180277                           0                           0
# 180279                           0                           1
# ...                            ...                         ...
# 446346                           0                           0
# 446348                           0                           0
# 446350                           0                           0
# 446352                           0                           0
# 446354                           0                           0
#
#         property_type_SINGLE_FAMILY  property_type_TOWNHOUSE
# 180271                            1                        0
# 180273                            1                        0
# 180275                            1                        0
# 180277                            1                        0
# 180279                            0                        0
# ...                             ...                      ...
# 446346                            1                        0
# 446348                            1                        0
# 446350                            1                        0
# 446352                            1                        0
# 446354                            1                        0
#
# [113297 rows x 1670 columns]

# %%
df.dtypes
# Out:
# price                          float64
# bedroom_number                 float64
# bathroom_number                float64
# living_space                   float64
# land_space                     float64
#                                 ...
# property_type_CONDO              uint8
# property_type_MANUFACTURED       uint8
# property_type_MULTI_FAMILY       uint8
# property_type_SINGLE_FAMILY      uint8
# property_type_TOWNHOUSE          uint8
# Length: 1670, dtype: object

# %%
df['price_per_sq_foot'] = df['price']/df['living_space']

# %%
q_low = df["bedroom_number"].quantile(0.01)
q_hi  = df["bedroom_number"].quantile(0.99)

df = df[(df["bedroom_number"] < q_hi) & (df["bedroom_number"] > q_low)]

# %%
q_low = df["bathroom_number"].quantile(0.01)
q_hi  = df["bathroom_number"].quantile(0.99)

df = df[(df["bathroom_number"] < q_hi) & (df["bathroom_number"] > q_low)]

# %%
q_low = df["living_space"].quantile(0.01)
q_hi  = df["living_space"].quantile(0.99)

df = df[(df["living_space"] < q_hi) & (df["living_space"] > q_low)]

# %%
q_low = df["land_space"].quantile(0.01)
q_hi  = df["land_space"].quantile(0.99)

df = df[(df["land_space"] < q_hi) & (df["land_space"] > q_low)]

# %%
q_low = df["price"].quantile(0.01)
q_hi  = df["price"].quantile(0.99)

df = df[(df["price"] < q_hi) & (df["price"] > q_low)]

# %%
q_low = df["price_per_sq_foot"].quantile(0.01)
q_hi  = df["price_per_sq_foot"].quantile(0.99)

df = df[(df["price_per_sq_foot"] < q_hi) & (df["price_per_sq_foot"] > q_low)]

# %%
description = df.describe(include='all')
description
# Out:
#               price  bedroom_number  bathroom_number  living_space  \
# count  9.797000e+04    97970.000000     97970.000000  97970.000000
# mean   4.239476e+05        3.469450         2.673614   2180.043187
# std    2.192554e+05        0.712618         0.860693    752.691660
# min    7.600000e+04        2.000000         1.000000    841.000000
# 25%    2.780000e+05        3.000000         2.000000   1619.000000
# 50%    3.750000e+05        3.000000         3.000000   2051.000000
# 75%    5.149000e+05        4.000000         3.000000   2628.000000
# max    1.629000e+06        5.000000         5.500000   4854.000000
#
#          land_space  postcode_11111  postcode_73870  postcode_75001  \
# count  9.797000e+04    97970.000000    97970.000000    97970.000000
# mean   2.699536e+04        0.000010        0.000010        0.000122
# std    8.769942e+04        0.003195        0.003195        0.011067
# min    1.454904e+03        0.000000        0.000000        0.000000
# 25%    6.534000e+03        0.000000        0.000000        0.000000
# 50%    8.424504e+03        0.000000        0.000000        0.000000
# 75%    1.067220e+04        0.000000        0.000000        0.000000
# max    1.181347e+06        1.000000        1.000000        1.000000
#
#        postcode_75002  postcode_75006  ...  postcode_79935  postcode_79936  \
# count    97970.000000    97970.000000  ...    97970.000000    97970.000000
# mean         0.001317        0.000735  ...        0.000133        0.000623
# std          0.036263        0.027100  ...        0.011519        0.024945
# min          0.000000        0.000000  ...        0.000000        0.000000
# 25%          0.000000        0.000000  ...        0.000000        0.000000
# 50%          0.000000        0.000000  ...        0.000000        0.000000
# 75%          0.000000        0.000000  ...        0.000000        0.000000
# max          1.000000        1.000000  ...        1.000000        1.000000
#
#        postcode_79938  postcode_97316  property_type_CONDO  \
# count    97970.000000    97970.000000         97970.000000
# mean         0.002470        0.000010             0.022813
# std          0.049639        0.003195             0.149308
# min          0.000000        0.000000             0.000000
# 25%          0.000000        0.000000             0.000000
# 50%          0.000000        0.000000             0.000000
# 75%          0.000000        0.000000             0.000000
# max          1.000000        1.000000             1.000000
#
#        property_type_MANUFACTURED  property_type_MULTI_FAMILY  \
# count                97970.000000                97970.000000
# mean                     0.020915                    0.009472
# std                      0.143099                    0.096864
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                      1.000000                    1.000000
#
#        property_type_SINGLE_FAMILY  property_type_TOWNHOUSE  price_per_sq_foot
# count                 97970.000000             97970.000000       97970.000000
# mean                      0.917485                 0.029203         193.412469
# std                       0.275149                 0.168375          67.283412
# min                       0.000000                 0.000000          70.511464
# 25%                       1.000000                 0.000000         149.907749
# 50%                       1.000000                 0.000000         182.256264
# 75%                       1.000000                 0.000000         222.222222
# max                       1.000000                 1.000000         517.160320
#
# [8 rows x 1671 columns]

# %%
features=df.describe().columns.drop(['price','price_per_sq_foot'])
features
# Out:
# Index(['bedroom_number', 'bathroom_number', 'living_space', 'land_space',
#        'postcode_11111', 'postcode_73870', 'postcode_75001', 'postcode_75002',
#        'postcode_75006', 'postcode_75007',
#        ...
#        'postcode_79934', 'postcode_79935', 'postcode_79936', 'postcode_79938',
#        'postcode_97316', 'property_type_CONDO', 'property_type_MANUFACTURED',
#        'property_type_MULTI_FAMILY', 'property_type_SINGLE_FAMILY',
#        'property_type_TOWNHOUSE'],
#       dtype='object', length=1669)

# %%
targets=['price','price_per_sq_foot']
targets
# Out:
# ['price', 'price_per_sq_foot']

# %%
X=df[features]
X
# Out:
#         bedroom_number  bathroom_number  living_space  land_space  \
# 180271             5.0              3.0        1692.0    6969.600
# 180273             4.0              2.0        1650.0   12632.400
# 180277             4.0              3.0        3119.0   15246.000
# 180279             3.0              3.0        3267.0    6000.000
# 180281             4.0              2.0        1800.0    6098.400
# ...                ...              ...           ...         ...
# 446346             3.0              2.0        1717.0    8145.720
# 446348             3.0              3.0        1754.0    3920.400
# 446350             4.0              3.0        2068.0    4356.000
# 446352             4.0              3.0        2111.0    4299.372
# 446354             3.0              2.0        1848.0    9016.920
#
#         postcode_11111  postcode_73870  postcode_75001  postcode_75002  \
# 180271               0               0               0               0
# 180273               0               0               0               0
# 180277               0               0               0               0
# 180279               0               0               0               0
# 180281               0               0               0               0
# ...                ...             ...             ...             ...
# 446346               0               0               0               0
# 446348               0               0               0               0
# 446350               0               0               0               0
# 446352               0               0               0               0
# 446354               0               0               0               0
#
#         postcode_75006  postcode_75007  ...  postcode_79934  postcode_79935  \
# 180271               0               0  ...               0               0
# 180273               0               0  ...               0               0
# 180277               0               0  ...               0               0
# 180279               0               0  ...               0               0
# 180281               0               0  ...               0               0
# ...                ...             ...  ...             ...             ...
# 446346               0               0  ...               0               0
# 446348               0               0  ...               0               0
# 446350               0               0  ...               0               0
# 446352               0               0  ...               0               0
# 446354               0               0  ...               0               0
#
#         postcode_79936  postcode_79938  postcode_97316  property_type_CONDO  \
# 180271               0               0               0                    0
# 180273               0               0               0                    0
# 180277               0               0               0                    0
# 180279               0               0               0                    0
# 180281               0               0               0                    0
# ...                ...             ...             ...                  ...
# 446346               0               0               0                    0
# 446348               0               0               0                    0
# 446350               0               0               0                    0
# 446352               0               0               0                    0
# 446354               0               0               0                    0
#
#         property_type_MANUFACTURED  property_type_MULTI_FAMILY  \
# 180271                           0                           0
# 180273                           0                           0
# 180277                           0                           0
# 180279                           0                           1
# 180281                           0                           0
# ...                            ...                         ...
# 446346                           0                           0
# 446348                           0                           0
# 446350                           0                           0
# 446352                           0                           0
# 446354                           0                           0
#
#         property_type_SINGLE_FAMILY  property_type_TOWNHOUSE
# 180271                            1                        0
# 180273                            1                        0
# 180277                            1                        0
# 180279                            0                        0
# 180281                            1                        0
# ...                             ...                      ...
# 446346                            1                        0
# 446348                            1                        0
# 446350                            1                        0
# 446352                            1                        0
# 446354                            1                        0
#
# [97970 rows x 1669 columns]

# %%
y=df[targets[0]]
y
# Out:
# 180271    239500.0
# 180273    165000.0
# 180277    414700.0
# 180279    260000.0
# 180281    174950.0
#             ...
# 446346    393000.0
# 446348    315000.0
# 446350    360000.0
# 446352    447000.0
# 446354    377000.0
# Name: price, Length: 97970, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.3,random_state=42)
len(X_train),len(X_test),len(y_train),len(y_test)
# Out:
# (68579, 29391, 68579, 29391)

# %%
numeric=['bedroom_number', 'bathroom_number', 'living_space', 'land_space']
sc=StandardScaler()
X_train[numeric]=sc.fit_transform(X_train[numeric])
X_test[numeric]=sc.transform(X_test[numeric])

# %% [markdown]
# **Linear Regression Model**

# %%
model = LinearRegression()
model.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_test,y_pred))
print(metrics.mean_squared_error(y_test,y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 3288691304147.942
# 1.5162697973816646e+28
# 123136907439713.81

# %%
model.score(X_train , y_train)
# Out:
# 0.7561690487431427

# %% [markdown]
# **Ridge Regression Model**

# %%
clf = Ridge(alpha=0.1)
clf.fit(X_train , y_train)
# Out:
# Ridge(alpha=0.1)

# %%
clf.score(X_train , y_train)
# Out:
# 0.756147034854444

# %% [markdown]
# **Lasso Regression Model**

# %%
clf1 = Lasso(alpha=0.1)
clf1.fit(X_train , y_train)
# Out:
# Lasso(alpha=0.1)

# %%
clf.score(X_train , y_train)
# Out:
# 0.756147034854444
